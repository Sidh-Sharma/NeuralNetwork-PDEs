# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from itertools import product

# %%
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)

# use gpu
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


nu = 0.01 / np.pi  # viscosity
x_min, x_max = -1.0, 1.0
t_min, t_max = 0.0, 1.0

# %%
def generate_data(n_points=10000):
    
    x_f = torch.FloatTensor(n_points, 1).uniform_(x_min, x_max).to(device)
    t_f = torch.FloatTensor(n_points, 1).uniform_(t_min, t_max).to(device)

    
    n0 = n_points // 10
    x0 = torch.linspace(x_min, x_max, n0).view(-1, 1).to(device)
    t0 = torch.zeros_like(x0).to(device)
    u0 = -torch.sin(np.pi * x0)

    
    nb = n_points // 10
    t_b = torch.linspace(t_min, t_max, nb).view(-1, 1).to(device)
    x_b_left = x_min * torch.ones_like(t_b).to(device)
    x_b_right = x_max * torch.ones_like(t_b).to(device)
    
    return x_f, t_f, x0, t0, u0, x_b_left, t_b, x_b_right

# %%
class PINN(nn.Module):
    def __init__(self, layers):
        super(PINN, self).__init__()
        self.layers = nn.ModuleList()
        num_layers = len(layers)
        
        for i in range(num_layers - 1):
            linear = nn.Linear(layers[i], layers[i + 1])
            nn.init.xavier_normal_(linear.weight)
            nn.init.zeros_(linear.bias)
            self.layers.append(linear)
            
        self.num_layers = num_layers

    def forward(self, x):
        for i, layer in enumerate(self.layers[:-1]):
            x = layer(x)
            # Use GELU for all hidden layers except the last one which uses Tanh.
            if i == len(self.layers) - 2:
                x = torch.tanh(x)
            else:
                x = torch.nn.functional.gelu(x)
        return self.layers[-1](x)

# %%
def compute_derivatives(net, x, t):
    X = torch.cat([x, t], dim=1).requires_grad_(True)
    u = net(X)
    grad_u = autograd.grad(u, X, torch.ones_like(u), create_graph=True, retain_graph=True)[0]
    u_x, u_t = grad_u[:, 0:1], grad_u[:, 1:2]
    u_xx = autograd.grad(u_x, X, torch.ones_like(u_x), create_graph=True, retain_graph=True)[0][:, 0:1]
    return u, u_x, u_t, u_xx

def loss_function(net, x_f, t_f, x0, t0, u0, x_b_left, t_b, x_b_right,
                  nu, weight_f=1.0, weight_ic=5.0, weight_bc=5.0):

    x_f_temp = x_f.detach().requires_grad_(True)
    t_f_temp = t_f.detach().requires_grad_(True)
    
   
    u, u_x, u_t, u_xx = compute_derivatives(net, x_f_temp, t_f_temp)
    f_pred = u_t + u * u_x - nu * u_xx
    loss_f = torch.mean(f_pred ** 2)
    
    
    u_pred_0 = net(torch.cat([x0, t0], dim=1))
    loss_ic = torch.mean((u_pred_0 - u0) ** 2)
    
    
    u_pred_left = net(torch.cat([x_b_left, t_b], dim=1))
    u_pred_right = net(torch.cat([x_b_right, t_b], dim=1))
    loss_bc = torch.mean(u_pred_left ** 2) + torch.mean(u_pred_right ** 2)
    
    total_loss = weight_f * loss_f + weight_ic * loss_ic + weight_bc * loss_bc
    return total_loss, loss_f, loss_ic, loss_bc

# %%
def train_hybrid(net, data, adam_epochs, adam_lr, lbfgs_epochs, lbfgs_lr,
                 weight_f, weight_ic, weight_bc, print_every=500):
    x_f, t_f, x0, t0, u0, x_b_left, t_b, x_b_right = data
    loss_history = []
    start_time = datetime.now()
    
    # Phase 1: Adam optimizer
    print("Phase 1: Training with Adam optimizer")
    optimizer_adam = optim.Adam(net.parameters(), lr=adam_lr)
    for epoch in range(adam_epochs):
        optimizer_adam.zero_grad()
        loss, loss_f, loss_ic, loss_bc = loss_function(
            net, x_f, t_f, x0, t0, u0,
            x_b_left, t_b, x_b_right, nu,
            weight_f, weight_ic, weight_bc
        )
        loss.backward()
        optimizer_adam.step()
        loss_history.append(loss.item())
        
        if epoch % print_every == 0 or epoch == adam_epochs - 1:
            elapsed = datetime.now() - start_time
            print(f'Adam Epoch {epoch:05d} | Time: {elapsed} | '
                  f'Loss: {loss.item():.4e} | '
                  f'PDE: {loss_f.item():.4e} | '
                  f'IC: {loss_ic.item():.4e} | '
                  f'BC: {loss_bc.item():.4e}')
    
    adam_transition = len(loss_history)
    
    # Phase 2: L-BFGS optimizer
    print("\nPhase 2: Refinement with L-BFGS optimizer")
    optimizer_lbfgs = optim.LBFGS(net.parameters(),
                                  lr=lbfgs_lr,
                                  max_iter=20,
                                  max_eval=25,
                                  history_size=50,
                                  line_search_fn='strong_wolfe')
    
    def closure():
        optimizer_lbfgs.zero_grad()
        loss, _, _, _ = loss_function(
            net, x_f, t_f, x0, t0, u0,
            x_b_left, t_b, x_b_right, nu,
            weight_f, weight_ic, weight_bc
        )
        loss.backward()
        return loss
    
    for epoch in range(lbfgs_epochs):
        loss = optimizer_lbfgs.step(closure)
        loss_history.append(loss.item())
        if epoch % print_every == 0 or epoch == lbfgs_epochs - 1:
            print(f'L-BFGS Epoch {epoch:04d} | Loss: {loss.item():.4e}')
    
    return net, loss_history, adam_transition


def evaluate_model(net, data, weight_f, weight_ic, weight_bc):
    
    net.eval()
   
    loss, loss_f, loss_ic, loss_bc = loss_function(
        net, *data, nu, weight_f, weight_ic, weight_bc
    )
    net.train()
    return loss.item()

# %%
def visualize_solution(net, nx=100, nt=100):
    x = torch.linspace(x_min, x_max, nx).view(-1, 1).to(device)
    t = torch.linspace(t_min, t_max, nt).view(-1, 1).to(device)
    
    X, T = torch.meshgrid(x.squeeze(), t.squeeze(), indexing='ij')  # Meshgrid for 2D representation
    X_flat = X.reshape(-1, 1)
    T_flat = T.reshape(-1, 1)
    input_pts = torch.cat([X_flat, T_flat], dim=1)
    
    u_pred = net(input_pts).cpu().detach().numpy()
    u_grid = u_pred.reshape(nx, nt)
    
    plt.figure(figsize=(12, 8))
    plt.contourf(T.cpu().numpy(), X.cpu().numpy(), u_grid, 50, cmap='rainbow')  
    plt.colorbar(label='u(x,t)')
    plt.xlabel('t')
    plt.ylabel('x')
    plt.title(f'PINN Solution to Burgers Equation (ν={nu:.4f})')
    plt.show()
    
    # Snapshots at selected time points
    t_snapshots = [0.0, 0.25, 0.5, 0.75, 1.0]
    plt.figure(figsize=(15, 7))
    for i, t_val in enumerate(t_snapshots):
        t_idx = int(t_val * (nt - 1))
        plt.subplot(1, len(t_snapshots), i + 1)
        plt.plot(x.cpu().numpy(), u_grid[:, t_idx])
        plt.ylim([-1.1, 1.1])
        plt.grid(True)
        plt.title(f't = {t_val:.2f}')
        if i == 0:
            plt.ylabel('u(x,t)')
        plt.xlabel('x')
    plt.tight_layout()
    plt.show()

# %%
def grid_search(train_data, val_data, hyperparams, save_dir='saved_models'):
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    
    best_val_loss = np.inf
    best_config = None
    best_state = None
    
    for (arch, wf, wic, wbc, adam_lr, adam_epochs, lbfgs_lr, lbfgs_epochs) in product(
            hyperparams['architecture'],
            hyperparams['weight_f'],
            hyperparams['weight_ic'],
            hyperparams['weight_bc'],
            hyperparams['adam_lr'],
            hyperparams['adam_epochs'],
            hyperparams['lbfgs_lr'],
            hyperparams['lbfgs_epochs']):
        
        print("\n" + "=" * 80)
        print(f"Training with configuration:\n"
              f"Architecture: {arch}\n"
              f"Loss Weights -> PDE: {wf}, IC: {wic}, BC: {wbc}\n"
              f"Adam: lr={adam_lr}, epochs={adam_epochs} | LBFGS: lr={lbfgs_lr}, epochs={lbfgs_epochs}")
        
        net = PINN(arch).to(device)
        trained_net, loss_history, adam_transition = train_hybrid(
            net, train_data,
            adam_epochs=adam_epochs,
            adam_lr=adam_lr,
            lbfgs_epochs=lbfgs_epochs,
            lbfgs_lr=lbfgs_lr,
            weight_f=wf,
            weight_ic=wic,
            weight_bc=wbc,
            print_every=adam_epochs // 10 if adam_epochs >= 10 else 1
        )
        val_loss = evaluate_model(trained_net, val_data, wf, wic, wbc)
        print(f"Validation Loss: {val_loss:.4e}")
        
        config_name = (f"arch{'-'.join(map(str, arch))}_wf{wf}_wic{wic}_wbc{wbc}_"
                       f"adam{adam_lr}_{adam_epochs}_lbfgs{lbfgs_lr}_{lbfgs_epochs}")
        model_path = os.path.join(save_dir, f"{config_name}.pt")
        torch.save(trained_net.state_dict(), model_path)
        print(f"Model saved at: {model_path}")
        
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_config = {
                'architecture': arch,
                'weight_f': wf,
                'weight_ic': wic,
                'weight_bc': wbc,
                'adam_lr': adam_lr,
                'adam_epochs': adam_epochs,
                'lbfgs_lr': lbfgs_lr,
                'lbfgs_epochs': lbfgs_epochs,
                'model_path': model_path
            }
            best_state = trained_net.state_dict()
    
    print("\n" + "=" * 80)
    print("Grid Search Complete!")
    print(f"Best Validation Loss: {best_val_loss:.4e}")
    print("Best Hyperparameters:")
    for key, value in best_config.items():
        print(f"  {key}: {value}")
    
    return best_config, best_state

# %%
if __name__ == "__main__":
    print(f"Using device: {device}")
    print(f"Burgers equation with viscosity ν = {nu:.4f}")
    
    train_data = generate_data(n_points=10000)
    val_data = generate_data(n_points=2000)
    
    hyperparams = {
        'architecture': [
            [2, 16, 32, 16, 1],
            [2, 16, 64, 16, 1],
            [2, 16, 32, 8, 1]
        ],
        'weight_f': [1.0, 1.25, 1.5],
        'weight_ic': [5.0],
        'weight_bc': [5.0],
        'adam_lr': [0.005, 0.001],
        'adam_epochs': [5000, 10000],
        'lbfgs_lr': [0.01],
        'lbfgs_epochs': [100]
    }
    
    best_config, best_state = grid_search(train_data, val_data, hyperparams, save_dir='saved_models')
    
    best_arch = best_config['architecture']
    best_model = PINN(best_arch).to(device)
    best_model.load_state_dict(best_state)
    
    visualize_solution(best_model)
# Out:
# Using device: cuda
# Burgers equation with viscosity ν = 0.0032
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 16, 1]
# Loss Weights -> PDE: 1.0, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:825: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at ../aten/src/ATen/cuda/CublasHandlePool.cpp:135.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Adam Epoch 00000 | Time: 0:00:04.065443 | Loss: 2.9739e+00 | PDE: 4.2912e-03 | IC: 5.7838e-01 | BC: 1.5532e-02
# Adam Epoch 00500 | Time: 0:00:07.648842 | Loss: 2.8190e-01 | PDE: 2.0344e-01 | IC: 1.5262e-02 | BC: 4.3054e-04
# Adam Epoch 01000 | Time: 0:00:11.237168 | Loss: 1.7745e-01 | PDE: 1.3601e-01 | IC: 8.2018e-03 | BC: 8.7756e-05
# Adam Epoch 01500 | Time: 0:00:14.760237 | Loss: 1.5067e-01 | PDE: 1.1759e-01 | IC: 5.8268e-03 | BC: 7.8860e-04
# Adam Epoch 02000 | Time: 0:00:18.282228 | Loss: 8.1074e-02 | PDE: 5.3098e-02 | IC: 4.4391e-03 | BC: 1.1562e-03
# Adam Epoch 02500 | Time: 0:00:21.864866 | Loss: 4.3213e-02 | PDE: 3.4529e-02 | IC: 1.4574e-03 | BC: 2.7945e-04
# Adam Epoch 03000 | Time: 0:00:25.437825 | Loss: 2.4805e-02 | PDE: 2.1331e-02 | IC: 6.7809e-04 | BC: 1.6856e-05
# Adam Epoch 03500 | Time: 0:00:29.223363 | Loss: 2.1947e-02 | PDE: 1.7961e-02 | IC: 7.2872e-04 | BC: 6.8552e-05
# Adam Epoch 04000 | Time: 0:00:32.780978 | Loss: 1.8753e-02 | PDE: 1.6199e-02 | IC: 5.0330e-04 | BC: 7.5721e-06
# Adam Epoch 04500 | Time: 0:00:36.426720 | Loss: 1.7427e-02 | PDE: 1.5057e-02 | IC: 4.6733e-04 | BC: 6.7167e-06
# Adam Epoch 04999 | Time: 0:00:40.033602 | Loss: 1.6840e-02 | PDE: 1.4651e-02 | IC: 3.7362e-04 | BC: 6.4248e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.6570e-02
# L-BFGS Epoch 0099 | Loss: 8.6595e-03
# Validation Loss: 8.5728e-03
# Model saved at: saved_models/arch2-16-32-16-1_wf1.0_wic5.0_wbc5.0_adam0.005_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 16, 1]
# Loss Weights -> PDE: 1.0, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.008293 | Loss: 3.1989e+00 | PDE: 1.8945e-02 | IC: 5.8263e-01 | BC: 5.3362e-02
# Adam Epoch 01000 | Time: 0:00:07.205643 | Loss: 2.1763e-01 | PDE: 1.6248e-01 | IC: 1.0569e-02 | BC: 4.6078e-04
# Adam Epoch 02000 | Time: 0:00:14.346018 | Loss: 8.4337e-02 | PDE: 6.7553e-02 | IC: 3.0785e-03 | BC: 2.7841e-04
# Adam Epoch 03000 | Time: 0:00:21.548958 | Loss: 3.7403e-02 | PDE: 3.0873e-02 | IC: 1.1112e-03 | BC: 1.9466e-04
# Adam Epoch 04000 | Time: 0:00:28.846340 | Loss: 2.1523e-02 | PDE: 1.8413e-02 | IC: 6.0381e-04 | BC: 1.8221e-05
# Adam Epoch 05000 | Time: 0:00:35.993535 | Loss: 2.9503e-02 | PDE: 2.6366e-02 | IC: 4.2843e-04 | BC: 1.9902e-04
# Adam Epoch 06000 | Time: 0:00:43.181325 | Loss: 1.3304e-02 | PDE: 1.0763e-02 | IC: 4.5077e-04 | BC: 5.7378e-05
# Adam Epoch 07000 | Time: 0:00:50.367451 | Loss: 1.0595e-02 | PDE: 8.9165e-03 | IC: 2.9420e-04 | BC: 4.1566e-05
# Adam Epoch 08000 | Time: 0:00:57.579043 | Loss: 9.2276e-03 | PDE: 7.2617e-03 | IC: 2.3366e-04 | BC: 1.5953e-04
# Adam Epoch 09000 | Time: 0:01:04.722270 | Loss: 5.3307e-03 | PDE: 4.6536e-03 | IC: 1.2630e-04 | BC: 9.1368e-06
# Adam Epoch 09999 | Time: 0:01:11.907875 | Loss: 4.1690e-03 | PDE: 3.2330e-03 | IC: 1.7030e-04 | BC: 1.6889e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 3.6594e-03
# L-BFGS Epoch 0099 | Loss: 8.8990e-04
# Validation Loss: 9.1658e-04
# Model saved at: saved_models/arch2-16-32-16-1_wf1.0_wic5.0_wbc5.0_adam0.005_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 16, 1]
# Loss Weights -> PDE: 1.0, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.008920 | Loss: 2.8334e+00 | PDE: 3.0173e-02 | IC: 5.0057e-01 | BC: 6.0086e-02
# Adam Epoch 00500 | Time: 0:00:03.603772 | Loss: 3.2560e-01 | PDE: 2.1754e-01 | IC: 1.9518e-02 | BC: 2.0954e-03
# Adam Epoch 01000 | Time: 0:00:07.124060 | Loss: 2.3395e-01 | PDE: 1.6960e-01 | IC: 1.2380e-02 | BC: 4.9080e-04
# Adam Epoch 01500 | Time: 0:00:10.742184 | Loss: 1.7196e-01 | PDE: 1.2897e-01 | IC: 8.4990e-03 | BC: 9.7871e-05
# Adam Epoch 02000 | Time: 0:00:14.310831 | Loss: 1.6052e-01 | PDE: 1.2040e-01 | IC: 7.9404e-03 | BC: 8.4215e-05
# Adam Epoch 02500 | Time: 0:00:17.878905 | Loss: 1.3975e-01 | PDE: 1.0676e-01 | IC: 6.5501e-03 | BC: 4.8247e-05
# Adam Epoch 03000 | Time: 0:00:21.426961 | Loss: 8.9798e-02 | PDE: 6.7587e-02 | IC: 4.3711e-03 | BC: 7.1296e-05
# Adam Epoch 03500 | Time: 0:00:25.076481 | Loss: 7.0510e-02 | PDE: 5.2221e-02 | IC: 3.5697e-03 | BC: 8.8185e-05
# Adam Epoch 04000 | Time: 0:00:28.656981 | Loss: 5.6211e-02 | PDE: 4.1460e-02 | IC: 2.9244e-03 | BC: 2.5940e-05
# Adam Epoch 04500 | Time: 0:00:32.256702 | Loss: 4.8396e-02 | PDE: 3.6579e-02 | IC: 2.3482e-03 | BC: 1.5356e-05
# Adam Epoch 04999 | Time: 0:00:35.826418 | Loss: 4.1838e-02 | PDE: 3.2770e-02 | IC: 1.8042e-03 | BC: 9.2249e-06
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 4.1825e-02
# L-BFGS Epoch 0099 | Loss: 4.1824e-02
# Validation Loss: 4.7139e-02
# Model saved at: saved_models/arch2-16-32-16-1_wf1.0_wic5.0_wbc5.0_adam0.001_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 16, 1]
# Loss Weights -> PDE: 1.0, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007796 | Loss: 2.3793e+00 | PDE: 2.7432e-03 | IC: 4.6959e-01 | BC: 5.7319e-03
# Adam Epoch 01000 | Time: 0:00:07.179982 | Loss: 2.3424e-01 | PDE: 1.6601e-01 | IC: 1.2856e-02 | BC: 7.8915e-04
# Adam Epoch 02000 | Time: 0:00:14.363262 | Loss: 1.5335e-01 | PDE: 1.1929e-01 | IC: 6.7624e-03 | BC: 5.0452e-05
# Adam Epoch 03000 | Time: 0:00:21.628909 | Loss: 7.2698e-02 | PDE: 5.5445e-02 | IC: 3.4135e-03 | BC: 3.7102e-05
# Adam Epoch 04000 | Time: 0:00:28.855267 | Loss: 5.3080e-02 | PDE: 4.1961e-02 | IC: 2.1586e-03 | BC: 6.5128e-05
# Adam Epoch 05000 | Time: 0:00:36.054199 | Loss: 3.9869e-02 | PDE: 3.2366e-02 | IC: 1.4902e-03 | BC: 1.0376e-05
# Adam Epoch 06000 | Time: 0:00:43.202820 | Loss: 3.6694e-02 | PDE: 3.0690e-02 | IC: 1.1630e-03 | BC: 3.7693e-05
# Adam Epoch 07000 | Time: 0:00:50.440310 | Loss: 2.8875e-02 | PDE: 2.4047e-02 | IC: 9.6303e-04 | BC: 2.5883e-06
# Adam Epoch 08000 | Time: 0:00:57.605639 | Loss: 2.3872e-02 | PDE: 1.9842e-02 | IC: 8.0307e-04 | BC: 2.8713e-06
# Adam Epoch 09000 | Time: 0:01:04.741024 | Loss: 1.9450e-02 | PDE: 1.6216e-02 | IC: 6.4425e-04 | BC: 2.5249e-06
# Adam Epoch 09999 | Time: 0:01:11.888027 | Loss: 2.2749e-02 | PDE: 1.9103e-02 | IC: 6.4150e-04 | BC: 8.7677e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.8883e-02
# L-BFGS Epoch 0099 | Loss: 5.7421e-03
# Validation Loss: 4.9909e-03
# Model saved at: saved_models/arch2-16-32-16-1_wf1.0_wic5.0_wbc5.0_adam0.001_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 16, 1]
# Loss Weights -> PDE: 1.25, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007685 | Loss: 2.9051e+00 | PDE: 5.3637e-02 | IC: 5.4497e-01 | BC: 2.2651e-02
# Adam Epoch 00500 | Time: 0:00:03.549222 | Loss: 3.1968e-01 | PDE: 1.6833e-01 | IC: 2.0605e-02 | BC: 1.2493e-03
# Adam Epoch 01000 | Time: 0:00:07.154276 | Loss: 1.9746e-01 | PDE: 1.1360e-01 | IC: 1.1069e-02 | BC: 2.4482e-05
# Adam Epoch 01500 | Time: 0:00:10.794219 | Loss: 1.5263e-01 | PDE: 8.6741e-02 | IC: 8.7368e-03 | BC: 1.0454e-04
# Adam Epoch 02000 | Time: 0:00:14.329682 | Loss: 6.9261e-02 | PDE: 4.1433e-02 | IC: 3.4305e-03 | BC: 6.3453e-05
# Adam Epoch 02500 | Time: 0:00:18.065916 | Loss: 6.8131e-02 | PDE: 4.4571e-02 | IC: 2.1569e-03 | BC: 3.2654e-04
# Adam Epoch 03000 | Time: 0:00:21.638028 | Loss: 3.4410e-02 | PDE: 2.1306e-02 | IC: 1.5204e-03 | BC: 3.5053e-05
# Adam Epoch 03500 | Time: 0:00:25.202955 | Loss: 2.7513e-02 | PDE: 1.7391e-02 | IC: 1.1339e-03 | BC: 2.0897e-05
# Adam Epoch 04000 | Time: 0:00:28.783421 | Loss: 2.6754e-02 | PDE: 1.6400e-02 | IC: 1.1469e-03 | BC: 1.0382e-04
# Adam Epoch 04500 | Time: 0:00:32.327854 | Loss: 2.8359e-02 | PDE: 1.7554e-02 | IC: 9.4456e-04 | BC: 3.3862e-04
# Adam Epoch 04999 | Time: 0:00:35.881482 | Loss: 2.1161e-02 | PDE: 1.3774e-02 | IC: 7.0068e-04 | BC: 8.7886e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.9483e-02
# L-BFGS Epoch 0099 | Loss: 5.3384e-03
# Validation Loss: 5.9669e-03
# Model saved at: saved_models/arch2-16-32-16-1_wf1.25_wic5.0_wbc5.0_adam0.005_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 16, 1]
# Loss Weights -> PDE: 1.25, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007925 | Loss: 2.5000e+00 | PDE: 1.0096e-02 | IC: 4.7612e-01 | BC: 2.1345e-02
# Adam Epoch 01000 | Time: 0:00:07.240930 | Loss: 1.8675e-01 | PDE: 1.0602e-01 | IC: 1.0516e-02 | BC: 3.2902e-04
# Adam Epoch 02000 | Time: 0:00:14.407410 | Loss: 9.7362e-02 | PDE: 5.9043e-02 | IC: 3.1667e-03 | BC: 1.5450e-03
# Adam Epoch 03000 | Time: 0:00:21.723418 | Loss: 3.1469e-02 | PDE: 1.8641e-02 | IC: 1.6129e-03 | BC: 2.0599e-05
# Adam Epoch 04000 | Time: 0:00:28.872528 | Loss: 3.6788e-02 | PDE: 1.9235e-02 | IC: 2.4209e-03 | BC: 1.2779e-04
# Adam Epoch 05000 | Time: 0:00:36.046035 | Loss: 6.2801e-02 | PDE: 4.4873e-02 | IC: 6.0414e-04 | BC: 7.3776e-04
# Adam Epoch 06000 | Time: 0:00:43.203261 | Loss: 1.5145e-02 | PDE: 1.0353e-02 | IC: 4.3447e-04 | BC: 6.2075e-06
# Adam Epoch 07000 | Time: 0:00:50.366821 | Loss: 1.3934e-02 | PDE: 9.5133e-03 | IC: 4.0514e-04 | BC: 3.2772e-06
# Adam Epoch 08000 | Time: 0:00:57.680028 | Loss: 1.6140e-02 | PDE: 1.0448e-02 | IC: 5.8806e-04 | BC: 2.7954e-05
# Adam Epoch 09000 | Time: 0:01:04.819384 | Loss: 1.2846e-02 | PDE: 8.6950e-03 | IC: 3.9300e-04 | BC: 2.5203e-06
# Adam Epoch 09999 | Time: 0:01:11.960430 | Loss: 1.2459e-02 | PDE: 8.4298e-03 | IC: 3.8150e-04 | BC: 2.8296e-06
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.2457e-02
# L-BFGS Epoch 0099 | Loss: 1.2457e-02
# Validation Loss: 1.3257e-02
# Model saved at: saved_models/arch2-16-32-16-1_wf1.25_wic5.0_wbc5.0_adam0.005_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 16, 1]
# Loss Weights -> PDE: 1.25, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007929 | Loss: 2.6559e+00 | PDE: 2.5214e-02 | IC: 5.1213e-01 | BC: 1.2744e-02
# Adam Epoch 00500 | Time: 0:00:03.579572 | Loss: 3.9745e-01 | PDE: 1.9593e-01 | IC: 2.8430e-02 | BC: 2.0785e-03
# Adam Epoch 01000 | Time: 0:00:07.120987 | Loss: 3.1993e-01 | PDE: 1.7005e-01 | IC: 2.0385e-02 | BC: 1.0879e-03
# Adam Epoch 01500 | Time: 0:00:10.831628 | Loss: 2.1423e-01 | PDE: 1.2396e-01 | IC: 1.1671e-02 | BC: 1.8341e-04
# Adam Epoch 02000 | Time: 0:00:14.389753 | Loss: 1.9509e-01 | PDE: 1.1429e-01 | IC: 1.0369e-02 | BC: 7.6435e-05
# Adam Epoch 02500 | Time: 0:00:17.928580 | Loss: 1.7410e-01 | PDE: 1.0302e-01 | IC: 9.0307e-03 | BC: 3.4450e-05
# Adam Epoch 03000 | Time: 0:00:21.499843 | Loss: 1.1975e-01 | PDE: 7.3550e-02 | IC: 5.4929e-03 | BC: 6.8870e-05
# Adam Epoch 03500 | Time: 0:00:25.083212 | Loss: 8.4341e-02 | PDE: 5.1198e-02 | IC: 4.0293e-03 | BC: 3.9442e-05
# Adam Epoch 04000 | Time: 0:00:28.668948 | Loss: 6.3115e-02 | PDE: 3.8386e-02 | IC: 3.0067e-03 | BC: 1.9664e-05
# Adam Epoch 04500 | Time: 0:00:32.244226 | Loss: 9.8112e-02 | PDE: 6.8167e-02 | IC: 2.3004e-03 | BC: 2.8043e-04
# Adam Epoch 04999 | Time: 0:00:35.812669 | Loss: 4.3402e-02 | PDE: 2.6150e-02 | IC: 2.1200e-03 | BC: 2.2928e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 4.3400e-02
# L-BFGS Epoch 0099 | Loss: 4.3388e-02
# Validation Loss: 4.2866e-02
# Model saved at: saved_models/arch2-16-32-16-1_wf1.25_wic5.0_wbc5.0_adam0.001_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 16, 1]
# Loss Weights -> PDE: 1.25, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007674 | Loss: 2.4217e+00 | PDE: 1.1830e-03 | IC: 3.9359e-01 | BC: 9.0463e-02
# Adam Epoch 01000 | Time: 0:00:07.288305 | Loss: 2.2543e-01 | PDE: 1.2886e-01 | IC: 1.2672e-02 | BC: 1.9902e-04
# Adam Epoch 02000 | Time: 0:00:14.369475 | Loss: 1.9988e-01 | PDE: 1.1565e-01 | IC: 1.0993e-02 | BC: 7.1681e-05
# Adam Epoch 03000 | Time: 0:00:21.502097 | Loss: 1.3787e-01 | PDE: 7.8835e-02 | IC: 7.6002e-03 | BC: 2.6507e-04
# Adam Epoch 04000 | Time: 0:00:28.683201 | Loss: 6.1858e-02 | PDE: 3.7757e-02 | IC: 2.9109e-03 | BC: 2.1281e-05
# Adam Epoch 05000 | Time: 0:00:35.955099 | Loss: 4.8570e-02 | PDE: 3.1023e-02 | IC: 1.9455e-03 | BC: 1.2676e-05
# Adam Epoch 06000 | Time: 0:00:42.999151 | Loss: 4.0635e-02 | PDE: 2.6723e-02 | IC: 1.4344e-03 | BC: 1.1949e-05
# Adam Epoch 07000 | Time: 0:00:50.133588 | Loss: 3.5792e-02 | PDE: 2.3705e-02 | IC: 1.2216e-03 | BC: 1.0631e-05
# Adam Epoch 08000 | Time: 0:00:57.321993 | Loss: 3.2336e-02 | PDE: 2.1551e-02 | IC: 1.0723e-03 | BC: 7.2907e-06
# Adam Epoch 09000 | Time: 0:01:04.392098 | Loss: 3.6515e-02 | PDE: 2.4729e-02 | IC: 9.6605e-04 | BC: 1.5461e-04
# Adam Epoch 09999 | Time: 0:01:11.654997 | Loss: 2.7136e-02 | PDE: 1.8305e-02 | IC: 8.4354e-04 | BC: 7.6114e-06
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 2.7134e-02
# L-BFGS Epoch 0099 | Loss: 2.7134e-02
# Validation Loss: 3.7679e-02
# Model saved at: saved_models/arch2-16-32-16-1_wf1.25_wic5.0_wbc5.0_adam0.001_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 16, 1]
# Loss Weights -> PDE: 1.5, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007864 | Loss: 3.2172e+00 | PDE: 7.0864e-02 | IC: 5.4082e-01 | BC: 8.1354e-02
# Adam Epoch 00500 | Time: 0:00:03.619758 | Loss: 3.8443e-01 | PDE: 1.5963e-01 | IC: 2.7901e-02 | BC: 1.0974e-03
# Adam Epoch 01000 | Time: 0:00:07.196192 | Loss: 2.1222e-01 | PDE: 9.5357e-02 | IC: 1.3765e-02 | BC: 7.2693e-05
# Adam Epoch 01500 | Time: 0:00:10.786836 | Loss: 1.2563e-01 | PDE: 5.9919e-02 | IC: 7.0423e-03 | BC: 1.0723e-04
# Adam Epoch 02000 | Time: 0:00:14.380371 | Loss: 8.1692e-02 | PDE: 3.9807e-02 | IC: 4.1247e-03 | BC: 2.7165e-04
# Adam Epoch 02500 | Time: 0:00:17.958362 | Loss: 5.8489e-02 | PDE: 2.9692e-02 | IC: 2.7463e-03 | BC: 4.3899e-05
# Adam Epoch 03000 | Time: 0:00:21.551317 | Loss: 4.4385e-02 | PDE: 2.2939e-02 | IC: 1.9691e-03 | BC: 2.6182e-05
# Adam Epoch 03500 | Time: 0:00:25.388201 | Loss: 3.8230e-02 | PDE: 2.0368e-02 | IC: 1.3729e-03 | BC: 1.6269e-04
# Adam Epoch 04000 | Time: 0:00:28.954764 | Loss: 2.9695e-02 | PDE: 1.5600e-02 | IC: 1.2383e-03 | BC: 2.0771e-05
# Adam Epoch 04500 | Time: 0:00:32.539673 | Loss: 2.6659e-02 | PDE: 1.4176e-02 | IC: 1.0242e-03 | BC: 5.4731e-05
# Adam Epoch 04999 | Time: 0:00:36.075363 | Loss: 3.3085e-02 | PDE: 1.6632e-02 | IC: 1.2915e-03 | BC: 3.3601e-04
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 2.9815e-02
# L-BFGS Epoch 0099 | Loss: 5.5708e-03
# Validation Loss: 4.9137e-03
# Model saved at: saved_models/arch2-16-32-16-1_wf1.5_wic5.0_wbc5.0_adam0.005_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 16, 1]
# Loss Weights -> PDE: 1.5, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007644 | Loss: 2.8114e+00 | PDE: 1.9370e-02 | IC: 5.2819e-01 | BC: 2.8287e-02
# Adam Epoch 01000 | Time: 0:00:07.192631 | Loss: 2.3407e-01 | PDE: 1.1076e-01 | IC: 1.3250e-02 | BC: 3.3583e-04
# Adam Epoch 02000 | Time: 0:00:14.388757 | Loss: 1.1659e-01 | PDE: 5.6089e-02 | IC: 6.2706e-03 | BC: 2.2106e-04
# Adam Epoch 03000 | Time: 0:00:21.545759 | Loss: 5.8030e-02 | PDE: 2.9589e-02 | IC: 2.5438e-03 | BC: 1.8558e-04
# Adam Epoch 04000 | Time: 0:00:28.847342 | Loss: 3.1662e-02 | PDE: 1.7525e-02 | IC: 1.0666e-03 | BC: 8.1771e-06
# Adam Epoch 05000 | Time: 0:00:36.043500 | Loss: 2.2640e-02 | PDE: 1.2765e-02 | IC: 6.9085e-04 | BC: 7.7740e-06
# Adam Epoch 06000 | Time: 0:00:43.191921 | Loss: 1.8824e-02 | PDE: 1.0632e-02 | IC: 5.6932e-04 | BC: 5.9145e-06
# Adam Epoch 07000 | Time: 0:00:50.333070 | Loss: 1.6556e-02 | PDE: 9.3370e-03 | IC: 5.0413e-04 | BC: 5.9991e-06
# Adam Epoch 08000 | Time: 0:00:57.528655 | Loss: 1.5081e-02 | PDE: 8.5314e-03 | IC: 4.5386e-04 | BC: 2.9889e-06
# Adam Epoch 09000 | Time: 0:01:04.859992 | Loss: 1.4305e-02 | PDE: 7.9258e-03 | IC: 4.6240e-04 | BC: 2.0869e-05
# Adam Epoch 09999 | Time: 0:01:12.060897 | Loss: 1.3294e-02 | PDE: 7.5468e-03 | IC: 3.9241e-04 | BC: 2.4429e-06
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.3293e-02
# L-BFGS Epoch 0099 | Loss: 1.3293e-02
# Validation Loss: 1.2962e-02
# Model saved at: saved_models/arch2-16-32-16-1_wf1.5_wic5.0_wbc5.0_adam0.005_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 16, 1]
# Loss Weights -> PDE: 1.5, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007833 | Loss: 2.2906e+00 | PDE: 1.2249e-02 | IC: 4.4176e-01 | BC: 1.2683e-02
# Adam Epoch 00500 | Time: 0:00:03.572442 | Loss: 2.8975e-01 | PDE: 1.2408e-01 | IC: 1.9746e-02 | BC: 9.7983e-04
# Adam Epoch 01000 | Time: 0:00:07.183288 | Loss: 2.3598e-01 | PDE: 1.0955e-01 | IC: 1.4226e-02 | BC: 1.0372e-04
# Adam Epoch 01500 | Time: 0:00:10.754988 | Loss: 2.1603e-01 | PDE: 1.0098e-01 | IC: 1.2861e-02 | BC: 4.9881e-05
# Adam Epoch 02000 | Time: 0:00:14.328230 | Loss: 1.7122e-01 | PDE: 8.0590e-02 | IC: 1.0034e-02 | BC: 3.4138e-05
# Adam Epoch 02500 | Time: 0:00:18.117526 | Loss: 1.1653e-01 | PDE: 5.4427e-02 | IC: 6.9461e-03 | BC: 3.1597e-05
# Adam Epoch 03000 | Time: 0:00:21.658927 | Loss: 9.3764e-02 | PDE: 4.4841e-02 | IC: 5.2543e-03 | BC: 4.6236e-05
# Adam Epoch 03500 | Time: 0:00:25.225454 | Loss: 7.8388e-02 | PDE: 3.8654e-02 | IC: 4.0382e-03 | BC: 4.3302e-05
# Adam Epoch 04000 | Time: 0:00:28.821472 | Loss: 7.0610e-02 | PDE: 3.5854e-02 | IC: 3.2284e-03 | BC: 1.3729e-04
# Adam Epoch 04500 | Time: 0:00:32.381877 | Loss: 5.6964e-02 | PDE: 2.8951e-02 | IC: 2.6620e-03 | BC: 4.5400e-05
# Adam Epoch 04999 | Time: 0:00:35.943882 | Loss: 4.8765e-02 | PDE: 2.5048e-02 | IC: 2.2038e-03 | BC: 3.4574e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 4.8751e-02
# L-BFGS Epoch 0099 | Loss: 4.8751e-02
# Validation Loss: 6.2398e-02
# Model saved at: saved_models/arch2-16-32-16-1_wf1.5_wic5.0_wbc5.0_adam0.001_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 16, 1]
# Loss Weights -> PDE: 1.5, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007784 | Loss: 2.4996e+00 | PDE: 9.0265e-04 | IC: 4.9948e-01 | BC: 1.7881e-04
# Adam Epoch 01000 | Time: 0:00:07.152407 | Loss: 2.3668e-01 | PDE: 1.0873e-01 | IC: 1.4638e-02 | BC: 8.0037e-05
# Adam Epoch 02000 | Time: 0:00:14.435296 | Loss: 1.8927e-01 | PDE: 8.8039e-02 | IC: 1.1377e-02 | BC: 6.4351e-05
# Adam Epoch 03000 | Time: 0:00:21.620092 | Loss: 8.7200e-02 | PDE: 4.2385e-02 | IC: 4.6544e-03 | BC: 7.0123e-05
# Adam Epoch 04000 | Time: 0:00:28.768708 | Loss: 6.5679e-02 | PDE: 3.3521e-02 | IC: 3.0070e-03 | BC: 7.2486e-05
# Adam Epoch 05000 | Time: 0:00:35.860222 | Loss: 4.4017e-02 | PDE: 2.3224e-02 | IC: 1.7898e-03 | BC: 4.6325e-05
# Adam Epoch 06000 | Time: 0:00:43.083734 | Loss: 3.7180e-02 | PDE: 2.0331e-02 | IC: 1.2162e-03 | BC: 1.2043e-04
# Adam Epoch 07000 | Time: 0:00:50.257247 | Loss: 2.6423e-02 | PDE: 1.4574e-02 | IC: 8.8933e-04 | BC: 2.3041e-05
# Adam Epoch 08000 | Time: 0:00:57.382891 | Loss: 2.2919e-02 | PDE: 1.2691e-02 | IC: 7.5669e-04 | BC: 1.9700e-05
# Adam Epoch 09000 | Time: 0:01:04.579431 | Loss: 2.0698e-02 | PDE: 1.1488e-02 | IC: 6.7797e-04 | BC: 1.5297e-05
# Adam Epoch 09999 | Time: 0:01:11.695433 | Loss: 1.9040e-02 | PDE: 1.0577e-02 | IC: 6.2221e-04 | BC: 1.2818e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.9039e-02
# L-BFGS Epoch 0099 | Loss: 1.9039e-02
# Validation Loss: 2.3220e-02
# Model saved at: saved_models/arch2-16-32-16-1_wf1.5_wic5.0_wbc5.0_adam0.001_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 64, 16, 1]
# Loss Weights -> PDE: 1.0, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.008475 | Loss: 2.6364e+00 | PDE: 3.8289e-02 | IC: 4.7609e-01 | BC: 4.3537e-02
# Adam Epoch 00500 | Time: 0:00:03.538134 | Loss: 3.0443e-01 | PDE: 2.1536e-01 | IC: 1.7064e-02 | BC: 7.5062e-04
# Adam Epoch 01000 | Time: 0:00:07.109063 | Loss: 1.7600e-01 | PDE: 1.3603e-01 | IC: 7.8148e-03 | BC: 1.7776e-04
# Adam Epoch 01500 | Time: 0:00:10.658684 | Loss: 1.4376e-01 | PDE: 1.1057e-01 | IC: 6.5627e-03 | BC: 7.4225e-05
# Adam Epoch 02000 | Time: 0:00:14.221790 | Loss: 8.8505e-02 | PDE: 7.4925e-02 | IC: 2.3004e-03 | BC: 4.1565e-04
# Adam Epoch 02500 | Time: 0:00:17.761256 | Loss: 5.0906e-02 | PDE: 4.1784e-02 | IC: 1.8016e-03 | BC: 2.2750e-05
# Adam Epoch 03000 | Time: 0:00:21.292678 | Loss: 3.4650e-02 | PDE: 2.8744e-02 | IC: 1.1740e-03 | BC: 7.1759e-06
# Adam Epoch 03500 | Time: 0:00:24.883612 | Loss: 3.0795e-02 | PDE: 2.5613e-02 | IC: 1.0229e-03 | BC: 1.3512e-05
# Adam Epoch 04000 | Time: 0:00:28.449615 | Loss: 2.1729e-02 | PDE: 1.8689e-02 | IC: 5.9004e-04 | BC: 1.7892e-05
# Adam Epoch 04500 | Time: 0:00:32.096326 | Loss: 2.2829e-02 | PDE: 1.8999e-02 | IC: 7.2735e-04 | BC: 3.8475e-05
# Adam Epoch 04999 | Time: 0:00:35.666627 | Loss: 1.8805e-02 | PDE: 1.5629e-02 | IC: 6.1967e-04 | BC: 1.5540e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.9059e-02
# L-BFGS Epoch 0099 | Loss: 4.1115e-03
# Validation Loss: 4.0498e-03
# Model saved at: saved_models/arch2-16-64-16-1_wf1.0_wic5.0_wbc5.0_adam0.005_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 64, 16, 1]
# Loss Weights -> PDE: 1.0, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007536 | Loss: 2.4191e+00 | PDE: 1.1437e-02 | IC: 4.7687e-01 | BC: 4.6594e-03
# Adam Epoch 01000 | Time: 0:00:07.318784 | Loss: 1.7927e-01 | PDE: 1.2605e-01 | IC: 9.6701e-03 | BC: 9.7269e-04
# Adam Epoch 02000 | Time: 0:00:14.423160 | Loss: 7.6118e-02 | PDE: 5.9925e-02 | IC: 3.2014e-03 | BC: 3.7126e-05
# Adam Epoch 03000 | Time: 0:00:21.546787 | Loss: 3.5479e-02 | PDE: 2.9506e-02 | IC: 1.1757e-03 | BC: 1.8940e-05
# Adam Epoch 04000 | Time: 0:00:28.800241 | Loss: 2.9454e-02 | PDE: 2.4506e-02 | IC: 7.3015e-04 | BC: 2.5950e-04
# Adam Epoch 05000 | Time: 0:00:36.128055 | Loss: 1.8221e-02 | PDE: 1.5662e-02 | IC: 5.0699e-04 | BC: 4.7900e-06
# Adam Epoch 06000 | Time: 0:00:43.219824 | Loss: 1.5130e-02 | PDE: 1.3063e-02 | IC: 4.0819e-04 | BC: 5.1519e-06
# Adam Epoch 07000 | Time: 0:00:50.390721 | Loss: 1.3155e-02 | PDE: 1.1393e-02 | IC: 3.4862e-04 | BC: 3.8262e-06
# Adam Epoch 08000 | Time: 0:00:57.568627 | Loss: 1.1940e-02 | PDE: 1.0369e-02 | IC: 3.1246e-04 | BC: 1.7236e-06
# Adam Epoch 09000 | Time: 0:01:04.752273 | Loss: 2.7555e-02 | PDE: 2.2158e-02 | IC: 5.6050e-04 | BC: 5.1890e-04
# Adam Epoch 09999 | Time: 0:01:12.077456 | Loss: 1.0412e-02 | PDE: 9.1174e-03 | IC: 2.5090e-04 | BC: 7.9434e-06
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.0625e-02
# L-BFGS Epoch 0099 | Loss: 7.3260e-03
# Validation Loss: 7.5371e-03
# Model saved at: saved_models/arch2-16-64-16-1_wf1.0_wic5.0_wbc5.0_adam0.005_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 64, 16, 1]
# Loss Weights -> PDE: 1.0, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007837 | Loss: 2.6886e+00 | PDE: 4.9232e-03 | IC: 5.3269e-01 | BC: 4.0485e-03
# Adam Epoch 00500 | Time: 0:00:03.696056 | Loss: 3.4044e-01 | PDE: 2.2445e-01 | IC: 2.1134e-02 | BC: 2.0621e-03
# Adam Epoch 01000 | Time: 0:00:07.253075 | Loss: 2.6935e-01 | PDE: 1.9006e-01 | IC: 1.5010e-02 | BC: 8.4701e-04
# Adam Epoch 01500 | Time: 0:00:10.864823 | Loss: 1.8293e-01 | PDE: 1.3526e-01 | IC: 9.2871e-03 | BC: 2.4765e-04
# Adam Epoch 02000 | Time: 0:00:14.432358 | Loss: 1.5078e-01 | PDE: 1.1543e-01 | IC: 7.0417e-03 | BC: 2.8352e-05
# Adam Epoch 02500 | Time: 0:00:18.018729 | Loss: 8.4511e-02 | PDE: 6.2138e-02 | IC: 4.4413e-03 | BC: 3.3321e-05
# Adam Epoch 03000 | Time: 0:00:21.642415 | Loss: 5.6497e-02 | PDE: 4.3570e-02 | IC: 2.5562e-03 | BC: 2.9233e-05
# Adam Epoch 03500 | Time: 0:00:25.248649 | Loss: 4.9211e-02 | PDE: 3.8012e-02 | IC: 2.2096e-03 | BC: 3.0157e-05
# Adam Epoch 04000 | Time: 0:00:28.895925 | Loss: 4.2424e-02 | PDE: 3.2619e-02 | IC: 1.9462e-03 | BC: 1.4835e-05
# Adam Epoch 04500 | Time: 0:00:32.619914 | Loss: 3.7456e-02 | PDE: 2.8872e-02 | IC: 1.7073e-03 | BC: 9.5882e-06
# Adam Epoch 04999 | Time: 0:00:36.268681 | Loss: 3.3388e-02 | PDE: 2.5575e-02 | IC: 1.5514e-03 | BC: 1.1053e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 3.3320e-02
# L-BFGS Epoch 0099 | Loss: 3.2936e-02
# Validation Loss: 3.1997e-02
# Model saved at: saved_models/arch2-16-64-16-1_wf1.0_wic5.0_wbc5.0_adam0.001_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 64, 16, 1]
# Loss Weights -> PDE: 1.0, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007920 | Loss: 2.3280e+00 | PDE: 3.4027e-05 | IC: 4.4908e-01 | BC: 1.6506e-02
# Adam Epoch 01000 | Time: 0:00:07.136213 | Loss: 1.8788e-01 | PDE: 1.4035e-01 | IC: 9.4475e-03 | BC: 5.8351e-05
# Adam Epoch 02000 | Time: 0:00:14.296076 | Loss: 9.4712e-02 | PDE: 7.1794e-02 | IC: 4.5536e-03 | BC: 2.9857e-05
# Adam Epoch 03000 | Time: 0:00:21.475475 | Loss: 5.6542e-02 | PDE: 4.3868e-02 | IC: 2.5257e-03 | BC: 9.2461e-06
# Adam Epoch 04000 | Time: 0:00:28.852913 | Loss: 3.8562e-02 | PDE: 3.1341e-02 | IC: 1.4279e-03 | BC: 1.6431e-05
# Adam Epoch 05000 | Time: 0:00:35.979848 | Loss: 2.8892e-02 | PDE: 2.4365e-02 | IC: 8.9687e-04 | BC: 8.5567e-06
# Adam Epoch 06000 | Time: 0:00:43.101716 | Loss: 2.5417e-02 | PDE: 2.0594e-02 | IC: 9.3209e-04 | BC: 3.2487e-05
# Adam Epoch 07000 | Time: 0:00:50.305782 | Loss: 2.1310e-02 | PDE: 1.8493e-02 | IC: 5.5819e-04 | BC: 5.1704e-06
# Adam Epoch 08000 | Time: 0:00:57.511780 | Loss: 1.9196e-02 | PDE: 1.6938e-02 | IC: 4.4566e-04 | BC: 5.9434e-06
# Adam Epoch 09000 | Time: 0:01:04.650647 | Loss: 1.7698e-02 | PDE: 1.5740e-02 | IC: 3.8665e-04 | BC: 4.8815e-06
# Adam Epoch 09999 | Time: 0:01:11.748928 | Loss: 1.9418e-02 | PDE: 1.7761e-02 | IC: 3.0507e-04 | BC: 2.6208e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 2.0937e-02
# L-BFGS Epoch 0099 | Loss: 8.6237e-03
# Validation Loss: 1.0195e-02
# Model saved at: saved_models/arch2-16-64-16-1_wf1.0_wic5.0_wbc5.0_adam0.001_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 64, 16, 1]
# Loss Weights -> PDE: 1.25, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007563 | Loss: 3.1165e+00 | PDE: 2.7464e-02 | IC: 3.1138e-01 | BC: 3.0506e-01
# Adam Epoch 00500 | Time: 0:00:03.606783 | Loss: 3.4234e-01 | PDE: 1.8372e-01 | IC: 2.1426e-02 | BC: 1.1110e-03
# Adam Epoch 01000 | Time: 0:00:07.180213 | Loss: 1.9228e-01 | PDE: 1.0929e-01 | IC: 1.1010e-02 | BC: 1.2338e-04
# Adam Epoch 01500 | Time: 0:00:10.739524 | Loss: 8.5776e-02 | PDE: 5.3613e-02 | IC: 3.6943e-03 | BC: 5.7775e-05
# Adam Epoch 02000 | Time: 0:00:14.324299 | Loss: 3.9424e-02 | PDE: 2.5361e-02 | IC: 1.5223e-03 | BC: 2.2102e-05
# Adam Epoch 02500 | Time: 0:00:17.882053 | Loss: 2.8658e-02 | PDE: 1.8622e-02 | IC: 1.0585e-03 | BC: 1.7641e-05
# Adam Epoch 03000 | Time: 0:00:21.435852 | Loss: 2.6467e-02 | PDE: 1.7649e-02 | IC: 7.2498e-04 | BC: 1.5618e-04
# Adam Epoch 03500 | Time: 0:00:25.188742 | Loss: 2.1174e-02 | PDE: 1.3559e-02 | IC: 8.3302e-04 | BC: 1.1933e-05
# Adam Epoch 04000 | Time: 0:00:28.740826 | Loss: 1.9472e-02 | PDE: 1.2809e-02 | IC: 6.3093e-04 | BC: 6.1032e-05
# Adam Epoch 04500 | Time: 0:00:32.316115 | Loss: 1.6052e-02 | PDE: 1.0606e-02 | IC: 5.5226e-04 | BC: 6.5294e-06
# Adam Epoch 04999 | Time: 0:00:35.972814 | Loss: 1.4119e-02 | PDE: 9.3902e-03 | IC: 4.7048e-04 | BC: 5.6814e-06
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.4114e-02
# L-BFGS Epoch 0099 | Loss: 1.4113e-02
# Validation Loss: 1.4888e-02
# Model saved at: saved_models/arch2-16-64-16-1_wf1.25_wic5.0_wbc5.0_adam0.005_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 64, 16, 1]
# Loss Weights -> PDE: 1.25, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.008278 | Loss: 3.3053e+00 | PDE: 1.5347e-03 | IC: 6.1578e-01 | BC: 4.4901e-02
# Adam Epoch 01000 | Time: 0:00:07.193829 | Loss: 2.3703e-01 | PDE: 1.2334e-01 | IC: 1.5761e-02 | BC: 8.1006e-04
# Adam Epoch 02000 | Time: 0:00:14.290577 | Loss: 9.7120e-02 | PDE: 6.0568e-02 | IC: 4.1333e-03 | BC: 1.4859e-04
# Adam Epoch 03000 | Time: 0:00:21.567635 | Loss: 4.0040e-02 | PDE: 2.5939e-02 | IC: 1.4995e-03 | BC: 2.3587e-05
# Adam Epoch 04000 | Time: 0:00:28.704183 | Loss: 2.2683e-02 | PDE: 1.5424e-02 | IC: 6.6172e-04 | BC: 1.9054e-05
# Adam Epoch 05000 | Time: 0:00:35.796756 | Loss: 1.9627e-02 | PDE: 1.3316e-02 | IC: 5.5173e-04 | BC: 4.4786e-05
# Adam Epoch 06000 | Time: 0:00:42.908414 | Loss: 1.6622e-02 | PDE: 1.1060e-02 | IC: 5.5191e-04 | BC: 7.4545e-06
# Adam Epoch 07000 | Time: 0:00:50.137835 | Loss: 1.6841e-02 | PDE: 1.0589e-02 | IC: 6.8912e-04 | BC: 3.1908e-05
# Adam Epoch 08000 | Time: 0:00:57.274828 | Loss: 1.4096e-02 | PDE: 9.4250e-03 | IC: 4.5703e-04 | BC: 5.9805e-06
# Adam Epoch 09000 | Time: 0:01:04.342885 | Loss: 1.7540e-02 | PDE: 1.1494e-02 | IC: 4.6082e-04 | BC: 1.7366e-04
# Adam Epoch 09999 | Time: 0:01:11.501866 | Loss: 1.5346e-02 | PDE: 9.7837e-03 | IC: 5.2885e-04 | BC: 9.4498e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.4216e-02
# L-BFGS Epoch 0099 | Loss: 8.2988e-03
# Validation Loss: 9.0448e-03
# Model saved at: saved_models/arch2-16-64-16-1_wf1.25_wic5.0_wbc5.0_adam0.005_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 64, 16, 1]
# Loss Weights -> PDE: 1.25, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007793 | Loss: 2.4442e+00 | PDE: 3.1604e-02 | IC: 4.5707e-01 | BC: 2.3858e-02
# Adam Epoch 00500 | Time: 0:00:03.560090 | Loss: 3.2796e-01 | PDE: 1.6989e-01 | IC: 2.1003e-02 | BC: 2.1176e-03
# Adam Epoch 01000 | Time: 0:00:07.115712 | Loss: 2.1989e-01 | PDE: 1.2305e-01 | IC: 1.2853e-02 | BC: 3.6321e-04
# Adam Epoch 01500 | Time: 0:00:10.702443 | Loss: 1.9703e-01 | PDE: 1.1877e-01 | IC: 8.6309e-03 | BC: 1.0817e-03
# Adam Epoch 02000 | Time: 0:00:14.277491 | Loss: 1.5732e-01 | PDE: 9.4002e-02 | IC: 7.3508e-03 | BC: 6.1210e-04
# Adam Epoch 02500 | Time: 0:00:18.058813 | Loss: 9.8047e-02 | PDE: 6.0496e-02 | IC: 4.4332e-03 | BC: 5.2389e-05
# Adam Epoch 03000 | Time: 0:00:21.633328 | Loss: 7.6447e-02 | PDE: 4.8395e-02 | IC: 3.1418e-03 | BC: 4.8824e-05
# Adam Epoch 03500 | Time: 0:00:25.193902 | Loss: 6.3621e-02 | PDE: 4.0144e-02 | IC: 2.6552e-03 | BC: 3.2854e-05
# Adam Epoch 04000 | Time: 0:00:28.791043 | Loss: 6.5013e-02 | PDE: 4.1541e-02 | IC: 2.3989e-03 | BC: 2.1840e-04
# Adam Epoch 04500 | Time: 0:00:32.387995 | Loss: 4.6478e-02 | PDE: 2.8943e-02 | IC: 2.0439e-03 | BC: 1.6088e-05
# Adam Epoch 04999 | Time: 0:00:35.954311 | Loss: 4.3861e-02 | PDE: 2.7197e-02 | IC: 1.9426e-03 | BC: 3.0443e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 4.2866e-02
# L-BFGS Epoch 0099 | Loss: 4.1516e-02
# Validation Loss: 4.4749e-02
# Model saved at: saved_models/arch2-16-64-16-1_wf1.25_wic5.0_wbc5.0_adam0.001_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 64, 16, 1]
# Loss Weights -> PDE: 1.25, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007697 | Loss: 2.6762e+00 | PDE: 8.4284e-03 | IC: 3.8770e-01 | BC: 1.4542e-01
# Adam Epoch 01000 | Time: 0:00:07.232087 | Loss: 2.0755e-01 | PDE: 1.2050e-01 | IC: 1.1280e-02 | BC: 1.0519e-04
# Adam Epoch 02000 | Time: 0:00:14.404970 | Loss: 1.0706e-01 | PDE: 6.4827e-02 | IC: 5.0101e-03 | BC: 1.9417e-04
# Adam Epoch 03000 | Time: 0:00:21.577300 | Loss: 5.8422e-02 | PDE: 3.6798e-02 | IC: 2.4515e-03 | BC: 3.3356e-05
# Adam Epoch 04000 | Time: 0:00:28.822673 | Loss: 3.7806e-02 | PDE: 2.4378e-02 | IC: 1.4543e-03 | BC: 1.2539e-05
# Adam Epoch 05000 | Time: 0:00:36.078427 | Loss: 2.8807e-02 | PDE: 1.9211e-02 | IC: 9.4961e-04 | BC: 9.0005e-06
# Adam Epoch 06000 | Time: 0:00:43.513080 | Loss: 2.4719e-02 | PDE: 1.6744e-02 | IC: 7.4981e-04 | BC: 7.9006e-06
# Adam Epoch 07000 | Time: 0:00:50.692733 | Loss: 3.3956e-02 | PDE: 2.4012e-02 | IC: 6.9699e-04 | BC: 9.1209e-05
# Adam Epoch 08000 | Time: 0:00:57.829033 | Loss: 2.1085e-02 | PDE: 1.4569e-02 | IC: 5.6885e-04 | BC: 5.9453e-06
# Adam Epoch 09000 | Time: 0:01:04.981092 | Loss: 1.9886e-02 | PDE: 1.3785e-02 | IC: 5.2638e-04 | BC: 4.5861e-06
# Adam Epoch 09999 | Time: 0:01:12.245044 | Loss: 1.8890e-02 | PDE: 1.3160e-02 | IC: 4.8467e-04 | BC: 3.5191e-06
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.8889e-02
# L-BFGS Epoch 0099 | Loss: 1.8889e-02
# Validation Loss: 2.6352e-02
# Model saved at: saved_models/arch2-16-64-16-1_wf1.25_wic5.0_wbc5.0_adam0.001_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 64, 16, 1]
# Loss Weights -> PDE: 1.5, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007782 | Loss: 2.7469e+00 | PDE: 1.9667e-02 | IC: 5.3085e-01 | BC: 1.2642e-02
# Adam Epoch 00500 | Time: 0:00:03.600303 | Loss: 2.5677e-01 | PDE: 1.1908e-01 | IC: 1.5392e-02 | BC: 2.3866e-04
# Adam Epoch 01000 | Time: 0:00:07.204586 | Loss: 2.1104e-01 | PDE: 1.0043e-01 | IC: 1.2012e-02 | BC: 6.7174e-05
# Adam Epoch 01500 | Time: 0:00:10.769651 | Loss: 9.1157e-02 | PDE: 4.5147e-02 | IC: 4.5907e-03 | BC: 9.6420e-05
# Adam Epoch 02000 | Time: 0:00:14.376911 | Loss: 5.0678e-02 | PDE: 2.6915e-02 | IC: 2.0437e-03 | BC: 1.7484e-05
# Adam Epoch 02500 | Time: 0:00:17.890681 | Loss: 3.6890e-02 | PDE: 1.9872e-02 | IC: 1.4079e-03 | BC: 8.5109e-06
# Adam Epoch 03000 | Time: 0:00:21.422639 | Loss: 3.1661e-02 | PDE: 1.6963e-02 | IC: 1.2131e-03 | BC: 3.0140e-05
# Adam Epoch 03500 | Time: 0:00:24.994713 | Loss: 4.6438e-02 | PDE: 2.6188e-02 | IC: 1.0672e-03 | BC: 3.6402e-04
# Adam Epoch 04000 | Time: 0:00:28.616799 | Loss: 2.5949e-02 | PDE: 1.4203e-02 | IC: 9.1739e-04 | BC: 1.1594e-05
# Adam Epoch 04500 | Time: 0:00:32.169315 | Loss: 2.4387e-02 | PDE: 1.3671e-02 | IC: 7.7080e-04 | BC: 5.3324e-06
# Adam Epoch 04999 | Time: 0:00:35.743878 | Loss: 2.3509e-02 | PDE: 1.3063e-02 | IC: 7.7513e-04 | BC: 7.5478e-06
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 2.3542e-02
# L-BFGS Epoch 0099 | Loss: 2.3404e-02
# Validation Loss: 2.4330e-02
# Model saved at: saved_models/arch2-16-64-16-1_wf1.5_wic5.0_wbc5.0_adam0.005_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 64, 16, 1]
# Loss Weights -> PDE: 1.5, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007743 | Loss: 3.2512e+00 | PDE: 7.6369e-03 | IC: 5.9650e-01 | BC: 5.1448e-02
# Adam Epoch 01000 | Time: 0:00:07.148616 | Loss: 2.9345e-01 | PDE: 1.3326e-01 | IC: 1.8510e-02 | BC: 2.0302e-04
# Adam Epoch 02000 | Time: 0:00:14.227273 | Loss: 6.7559e-02 | PDE: 3.3811e-02 | IC: 3.3337e-03 | BC: 3.4861e-05
# Adam Epoch 03000 | Time: 0:00:21.449306 | Loss: 5.7560e-02 | PDE: 3.3581e-02 | IC: 1.1870e-03 | BC: 2.5070e-04
# Adam Epoch 04000 | Time: 0:00:28.641889 | Loss: 3.1933e-02 | PDE: 1.5714e-02 | IC: 1.5958e-03 | BC: 7.6736e-05
# Adam Epoch 05000 | Time: 0:00:35.796243 | Loss: 2.2172e-02 | PDE: 1.2175e-02 | IC: 7.7258e-04 | BC: 9.3902e-06
# Adam Epoch 06000 | Time: 0:00:42.921308 | Loss: 1.8231e-02 | PDE: 9.9928e-03 | IC: 6.4140e-04 | BC: 6.9305e-06
# Adam Epoch 07000 | Time: 0:00:50.080166 | Loss: 1.6180e-02 | PDE: 8.8641e-03 | IC: 5.7214e-04 | BC: 4.6974e-06
# Adam Epoch 08000 | Time: 0:00:57.262720 | Loss: 1.4948e-02 | PDE: 8.2443e-03 | IC: 5.0809e-04 | BC: 8.1797e-06
# Adam Epoch 09000 | Time: 0:01:04.419366 | Loss: 1.7743e-02 | PDE: 9.4040e-03 | IC: 5.3890e-04 | BC: 1.8846e-04
# Adam Epoch 09999 | Time: 0:01:11.545231 | Loss: 1.3055e-02 | PDE: 7.1826e-03 | IC: 4.5339e-04 | BC: 2.8912e-06
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.3119e-02
# L-BFGS Epoch 0099 | Loss: 1.2927e-02
# Validation Loss: 1.5240e-02
# Model saved at: saved_models/arch2-16-64-16-1_wf1.5_wic5.0_wbc5.0_adam0.005_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 64, 16, 1]
# Loss Weights -> PDE: 1.5, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007578 | Loss: 2.8900e+00 | PDE: 1.7616e-02 | IC: 5.3953e-01 | BC: 3.3191e-02
# Adam Epoch 00500 | Time: 0:00:03.579100 | Loss: 4.2670e-01 | PDE: 1.6908e-01 | IC: 3.1586e-02 | BC: 3.0300e-03
# Adam Epoch 01000 | Time: 0:00:07.274170 | Loss: 2.5123e-01 | PDE: 1.1290e-01 | IC: 1.5922e-02 | BC: 4.5462e-04
# Adam Epoch 01500 | Time: 0:00:10.860527 | Loss: 2.1495e-01 | PDE: 9.9820e-02 | IC: 1.2965e-02 | BC: 7.8418e-05
# Adam Epoch 02000 | Time: 0:00:14.452046 | Loss: 1.7276e-01 | PDE: 8.0888e-02 | IC: 1.0022e-02 | BC: 2.6245e-04
# Adam Epoch 02500 | Time: 0:00:18.026345 | Loss: 8.9145e-02 | PDE: 4.2653e-02 | IC: 4.9859e-03 | BC: 4.7262e-05
# Adam Epoch 03000 | Time: 0:00:21.609189 | Loss: 6.5892e-02 | PDE: 3.2672e-02 | IC: 3.3139e-03 | BC: 6.2835e-05
# Adam Epoch 03500 | Time: 0:00:25.171657 | Loss: 5.7513e-02 | PDE: 2.9493e-02 | IC: 2.5971e-03 | BC: 5.7582e-05
# Adam Epoch 04000 | Time: 0:00:28.703815 | Loss: 4.7599e-02 | PDE: 2.4630e-02 | IC: 2.0994e-03 | BC: 3.1539e-05
# Adam Epoch 04500 | Time: 0:00:32.306923 | Loss: 4.5483e-02 | PDE: 2.3380e-02 | IC: 2.0372e-03 | BC: 4.5354e-05
# Adam Epoch 04999 | Time: 0:00:35.886879 | Loss: 3.8851e-02 | PDE: 2.0732e-02 | IC: 1.5322e-03 | BC: 1.8594e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 3.8831e-02
# L-BFGS Epoch 0099 | Loss: 3.8830e-02
# Validation Loss: 4.8284e-02
# Model saved at: saved_models/arch2-16-64-16-1_wf1.5_wic5.0_wbc5.0_adam0.001_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 64, 16, 1]
# Loss Weights -> PDE: 1.5, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.008734 | Loss: 2.3303e+00 | PDE: 3.7256e-03 | IC: 4.5689e-01 | BC: 8.0460e-03
# Adam Epoch 01000 | Time: 0:00:07.199276 | Loss: 2.5396e-01 | PDE: 1.1713e-01 | IC: 1.5310e-02 | BC: 3.4391e-04
# Adam Epoch 02000 | Time: 0:00:14.352231 | Loss: 1.8361e-01 | PDE: 8.7189e-02 | IC: 1.0471e-02 | BC: 9.3709e-05
# Adam Epoch 03000 | Time: 0:00:21.542918 | Loss: 6.7337e-02 | PDE: 3.3506e-02 | IC: 3.3989e-03 | BC: 1.6964e-05
# Adam Epoch 04000 | Time: 0:00:28.670713 | Loss: 4.8897e-02 | PDE: 2.4557e-02 | IC: 2.4046e-03 | BC: 7.7501e-06
# Adam Epoch 05000 | Time: 0:00:36.041922 | Loss: 4.0570e-02 | PDE: 2.0482e-02 | IC: 1.9641e-03 | BC: 5.3425e-06
# Adam Epoch 06000 | Time: 0:00:43.246009 | Loss: 3.7370e-02 | PDE: 1.8661e-02 | IC: 1.8704e-03 | BC: 5.3455e-06
# Adam Epoch 07000 | Time: 0:00:50.353924 | Loss: 4.4114e-02 | PDE: 2.1084e-02 | IC: 2.3896e-03 | BC: 1.0784e-04
# Adam Epoch 08000 | Time: 0:00:57.502246 | Loss: 3.3542e-02 | PDE: 1.6577e-02 | IC: 1.7316e-03 | BC: 3.8273e-06
# Adam Epoch 09000 | Time: 0:01:04.812716 | Loss: 3.2444e-02 | PDE: 1.5924e-02 | IC: 1.7088e-03 | BC: 2.8334e-06
# Adam Epoch 09999 | Time: 0:01:11.993905 | Loss: 3.1572e-02 | PDE: 1.5332e-02 | IC: 1.7123e-03 | BC: 2.7160e-06
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 3.1557e-02
# L-BFGS Epoch 0099 | Loss: 3.1542e-02
# Validation Loss: 3.5720e-02
# Model saved at: saved_models/arch2-16-64-16-1_wf1.5_wic5.0_wbc5.0_adam0.001_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 8, 1]
# Loss Weights -> PDE: 1.0, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.008295 | Loss: 2.9151e+00 | PDE: 1.4474e-02 | IC: 5.4891e-01 | BC: 3.1208e-02
# Adam Epoch 00500 | Time: 0:00:03.556702 | Loss: 2.8797e-01 | PDE: 2.0310e-01 | IC: 1.5771e-02 | BC: 1.2033e-03
# Adam Epoch 01000 | Time: 0:00:07.136848 | Loss: 1.8428e-01 | PDE: 1.3681e-01 | IC: 9.3769e-03 | BC: 1.1761e-04
# Adam Epoch 01500 | Time: 0:00:10.710959 | Loss: 1.7049e-01 | PDE: 1.2890e-01 | IC: 8.2748e-03 | BC: 4.3302e-05
# Adam Epoch 02000 | Time: 0:00:14.253052 | Loss: 1.5842e-01 | PDE: 1.2062e-01 | IC: 7.5203e-03 | BC: 3.8558e-05
# Adam Epoch 02500 | Time: 0:00:17.848905 | Loss: 1.3314e-01 | PDE: 1.0430e-01 | IC: 5.7270e-03 | BC: 4.1179e-05
# Adam Epoch 03000 | Time: 0:00:21.566133 | Loss: 6.9683e-02 | PDE: 5.3832e-02 | IC: 3.1247e-03 | BC: 4.5442e-05
# Adam Epoch 03500 | Time: 0:00:25.087567 | Loss: 4.2090e-02 | PDE: 3.4047e-02 | IC: 1.4997e-03 | BC: 1.0903e-04
# Adam Epoch 04000 | Time: 0:00:28.652587 | Loss: 2.8197e-02 | PDE: 2.3101e-02 | IC: 9.7615e-04 | BC: 4.3048e-05
# Adam Epoch 04500 | Time: 0:00:32.211370 | Loss: 2.2907e-02 | PDE: 1.8690e-02 | IC: 8.1764e-04 | BC: 2.5670e-05
# Adam Epoch 04999 | Time: 0:00:35.838994 | Loss: 2.8738e-02 | PDE: 2.3373e-02 | IC: 7.8869e-04 | BC: 2.8430e-04
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 2.4211e-02
# L-BFGS Epoch 0099 | Loss: 5.3727e-03
# Validation Loss: 5.4220e-03
# Model saved at: saved_models/arch2-16-32-8-1_wf1.0_wic5.0_wbc5.0_adam0.005_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 8, 1]
# Loss Weights -> PDE: 1.0, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007781 | Loss: 2.3941e+00 | PDE: 4.3628e-04 | IC: 4.4392e-01 | BC: 3.4823e-02
# Adam Epoch 01000 | Time: 0:00:07.129630 | Loss: 6.5380e-02 | PDE: 5.2354e-02 | IC: 2.4462e-03 | BC: 1.5914e-04
# Adam Epoch 02000 | Time: 0:00:14.256131 | Loss: 3.3021e-02 | PDE: 2.7679e-02 | IC: 1.0329e-03 | BC: 3.5595e-05
# Adam Epoch 03000 | Time: 0:00:21.391756 | Loss: 2.9804e-02 | PDE: 2.4335e-02 | IC: 8.8813e-04 | BC: 2.0581e-04
# Adam Epoch 04000 | Time: 0:00:28.688900 | Loss: 1.9038e-02 | PDE: 1.6301e-02 | IC: 5.4065e-04 | BC: 6.7122e-06
# Adam Epoch 05000 | Time: 0:00:35.800296 | Loss: 1.7613e-02 | PDE: 1.5125e-02 | IC: 4.9117e-04 | BC: 6.5041e-06
# Adam Epoch 06000 | Time: 0:00:42.946688 | Loss: 1.6425e-02 | PDE: 1.4092e-02 | IC: 4.6184e-04 | BC: 4.7526e-06
# Adam Epoch 07000 | Time: 0:00:50.078231 | Loss: 1.5492e-02 | PDE: 1.3355e-02 | IC: 4.1231e-04 | BC: 1.5075e-05
# Adam Epoch 08000 | Time: 0:00:57.298604 | Loss: 2.3924e-02 | PDE: 2.0157e-02 | IC: 4.0995e-04 | BC: 3.4345e-04
# Adam Epoch 09000 | Time: 0:01:04.390386 | Loss: 2.0522e-02 | PDE: 1.7207e-02 | IC: 3.9920e-04 | BC: 2.6387e-04
# Adam Epoch 09999 | Time: 0:01:11.487016 | Loss: 1.4079e-02 | PDE: 1.2228e-02 | IC: 3.3473e-04 | BC: 3.5466e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.4368e-02
# L-BFGS Epoch 0099 | Loss: 1.1416e-02
# Validation Loss: 1.1901e-02
# Model saved at: saved_models/arch2-16-32-8-1_wf1.0_wic5.0_wbc5.0_adam0.005_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 8, 1]
# Loss Weights -> PDE: 1.0, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007871 | Loss: 2.4632e+00 | PDE: 1.2277e-04 | IC: 4.9041e-01 | BC: 2.1951e-03
# Adam Epoch 00500 | Time: 0:00:03.612127 | Loss: 3.0821e-01 | PDE: 2.1229e-01 | IC: 1.7642e-02 | BC: 1.5423e-03
# Adam Epoch 01000 | Time: 0:00:07.175676 | Loss: 1.9114e-01 | PDE: 1.4368e-01 | IC: 9.3338e-03 | BC: 1.5758e-04
# Adam Epoch 01500 | Time: 0:00:10.749012 | Loss: 1.6873e-01 | PDE: 1.3259e-01 | IC: 6.8645e-03 | BC: 3.6379e-04
# Adam Epoch 02000 | Time: 0:00:14.367447 | Loss: 1.3820e-01 | PDE: 1.0808e-01 | IC: 5.9582e-03 | BC: 6.7013e-05
# Adam Epoch 02500 | Time: 0:00:17.865200 | Loss: 7.8745e-02 | PDE: 6.3272e-02 | IC: 3.0101e-03 | BC: 8.4737e-05
# Adam Epoch 03000 | Time: 0:00:21.480851 | Loss: 6.4753e-02 | PDE: 5.2840e-02 | IC: 2.3113e-03 | BC: 7.1169e-05
# Adam Epoch 03500 | Time: 0:00:25.212628 | Loss: 4.9829e-02 | PDE: 4.2140e-02 | IC: 1.4900e-03 | BC: 4.7809e-05
# Adam Epoch 04000 | Time: 0:00:28.760113 | Loss: 5.5659e-02 | PDE: 4.6405e-02 | IC: 1.4728e-03 | BC: 3.7800e-04
# Adam Epoch 04500 | Time: 0:00:32.371332 | Loss: 3.8270e-02 | PDE: 3.2471e-02 | IC: 1.1130e-03 | BC: 4.6807e-05
# Adam Epoch 04999 | Time: 0:00:35.932357 | Loss: 3.4916e-02 | PDE: 2.9655e-02 | IC: 1.0139e-03 | BC: 3.8426e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 3.4804e-02
# L-BFGS Epoch 0099 | Loss: 1.9263e-02
# Validation Loss: 2.3126e-02
# Model saved at: saved_models/arch2-16-32-8-1_wf1.0_wic5.0_wbc5.0_adam0.001_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 8, 1]
# Loss Weights -> PDE: 1.0, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007873 | Loss: 2.5383e+00 | PDE: 3.9849e-02 | IC: 4.8234e-01 | BC: 1.7353e-02
# Adam Epoch 01000 | Time: 0:00:07.130720 | Loss: 1.9304e-01 | PDE: 1.4347e-01 | IC: 9.8269e-03 | BC: 8.7376e-05
# Adam Epoch 02000 | Time: 0:00:14.279335 | Loss: 1.6370e-01 | PDE: 1.2326e-01 | IC: 8.0625e-03 | BC: 2.5142e-05
# Adam Epoch 03000 | Time: 0:00:21.448225 | Loss: 1.4038e-01 | PDE: 1.0779e-01 | IC: 6.4792e-03 | BC: 3.9058e-05
# Adam Epoch 04000 | Time: 0:00:28.719492 | Loss: 6.4096e-02 | PDE: 5.1019e-02 | IC: 2.5136e-03 | BC: 1.0179e-04
# Adam Epoch 05000 | Time: 0:00:35.846397 | Loss: 3.5951e-02 | PDE: 2.9976e-02 | IC: 1.1612e-03 | BC: 3.3813e-05
# Adam Epoch 06000 | Time: 0:00:42.951041 | Loss: 2.9367e-02 | PDE: 2.4722e-02 | IC: 8.9903e-04 | BC: 2.9857e-05
# Adam Epoch 07000 | Time: 0:00:50.062793 | Loss: 2.3968e-02 | PDE: 2.0562e-02 | IC: 6.6616e-04 | BC: 1.5065e-05
# Adam Epoch 08000 | Time: 0:00:57.199563 | Loss: 2.0855e-02 | PDE: 1.7937e-02 | IC: 5.7325e-04 | BC: 1.0292e-05
# Adam Epoch 09000 | Time: 0:01:04.466891 | Loss: 1.8843e-02 | PDE: 1.6230e-02 | IC: 5.1353e-04 | BC: 8.8765e-06
# Adam Epoch 09999 | Time: 0:01:11.615507 | Loss: 1.7553e-02 | PDE: 1.5079e-02 | IC: 4.8719e-04 | BC: 7.7385e-06
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.7546e-02
# L-BFGS Epoch 0099 | Loss: 1.7543e-02
# Validation Loss: 1.9296e-02
# Model saved at: saved_models/arch2-16-32-8-1_wf1.0_wic5.0_wbc5.0_adam0.001_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 8, 1]
# Loss Weights -> PDE: 1.25, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007964 | Loss: 2.3266e+00 | PDE: 9.0406e-03 | IC: 4.1923e-01 | BC: 4.3818e-02
# Adam Epoch 00500 | Time: 0:00:03.592356 | Loss: 2.2322e-01 | PDE: 1.3009e-01 | IC: 1.1925e-02 | BC: 1.9588e-04
# Adam Epoch 01000 | Time: 0:00:07.159978 | Loss: 1.9422e-01 | PDE: 1.0952e-01 | IC: 1.1178e-02 | BC: 2.8614e-04
# Adam Epoch 01500 | Time: 0:00:10.779025 | Loss: 1.2756e-01 | PDE: 7.9470e-02 | IC: 4.8844e-03 | BC: 7.5980e-04
# Adam Epoch 02000 | Time: 0:00:14.320192 | Loss: 6.0597e-02 | PDE: 3.7940e-02 | IC: 2.5826e-03 | BC: 5.1947e-05
# Adam Epoch 02500 | Time: 0:00:18.023701 | Loss: 2.7001e-01 | PDE: 1.9051e-01 | IC: 2.8511e-03 | BC: 3.5234e-03
# Adam Epoch 03000 | Time: 0:00:21.585445 | Loss: 3.9058e-02 | PDE: 2.5486e-02 | IC: 1.4092e-03 | BC: 3.0964e-05
# Adam Epoch 03500 | Time: 0:00:25.122949 | Loss: 3.4653e-02 | PDE: 2.3370e-02 | IC: 1.0707e-03 | BC: 1.7658e-05
# Adam Epoch 04000 | Time: 0:00:28.672595 | Loss: 7.3403e-02 | PDE: 4.8766e-02 | IC: 1.7350e-03 | BC: 7.5429e-04
# Adam Epoch 04500 | Time: 0:00:32.224435 | Loss: 2.9504e-02 | PDE: 2.0096e-02 | IC: 8.6446e-04 | BC: 1.2200e-05
# Adam Epoch 04999 | Time: 0:00:35.741837 | Loss: 2.7348e-02 | PDE: 1.8620e-02 | IC: 8.0432e-04 | BC: 1.0240e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 2.7345e-02
# L-BFGS Epoch 0099 | Loss: 2.7340e-02
# Validation Loss: 2.7292e-02
# Model saved at: saved_models/arch2-16-32-8-1_wf1.25_wic5.0_wbc5.0_adam0.005_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 8, 1]
# Loss Weights -> PDE: 1.25, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.008018 | Loss: 2.5914e+00 | PDE: 1.5390e-02 | IC: 5.0400e-01 | BC: 1.0443e-02
# Adam Epoch 01000 | Time: 0:00:07.122422 | Loss: 1.9713e-01 | PDE: 1.1617e-01 | IC: 1.0073e-02 | BC: 3.1175e-04
# Adam Epoch 02000 | Time: 0:00:14.416700 | Loss: 6.4909e-02 | PDE: 3.9308e-02 | IC: 3.1069e-03 | BC: 4.8005e-05
# Adam Epoch 03000 | Time: 0:00:21.653263 | Loss: 4.0081e-02 | PDE: 2.5187e-02 | IC: 1.7064e-03 | BC: 1.3179e-05
# Adam Epoch 04000 | Time: 0:00:28.833839 | Loss: 3.0176e-02 | PDE: 1.9642e-02 | IC: 1.1121e-03 | BC: 1.2580e-05
# Adam Epoch 05000 | Time: 0:00:36.044767 | Loss: 2.5545e-02 | PDE: 1.6890e-02 | IC: 8.6943e-04 | BC: 1.6928e-05
# Adam Epoch 06000 | Time: 0:00:43.303857 | Loss: 4.0809e-02 | PDE: 2.8962e-02 | IC: 7.0632e-04 | BC: 2.1481e-04
# Adam Epoch 07000 | Time: 0:00:50.436836 | Loss: 1.8669e-02 | PDE: 1.2615e-02 | IC: 5.7195e-04 | BC: 8.0791e-06
# Adam Epoch 08000 | Time: 0:00:57.548003 | Loss: 3.0937e-02 | PDE: 1.9215e-02 | IC: 9.0892e-04 | BC: 4.7486e-04
# Adam Epoch 09000 | Time: 0:01:04.709806 | Loss: 1.6870e-02 | PDE: 1.1383e-02 | IC: 5.2207e-04 | BC: 6.3008e-06
# Adam Epoch 09999 | Time: 0:01:12.013676 | Loss: 1.8780e-02 | PDE: 1.1967e-02 | IC: 6.4270e-04 | BC: 1.2150e-04
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.9172e-02
# L-BFGS Epoch 0099 | Loss: 1.3704e-02
# Validation Loss: 1.9199e-02
# Model saved at: saved_models/arch2-16-32-8-1_wf1.25_wic5.0_wbc5.0_adam0.005_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 8, 1]
# Loss Weights -> PDE: 1.25, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007672 | Loss: 2.6184e+00 | PDE: 9.7037e-03 | IC: 5.1515e-01 | BC: 6.1012e-03
# Adam Epoch 00500 | Time: 0:00:03.589879 | Loss: 3.6335e-01 | PDE: 1.8962e-01 | IC: 2.3557e-02 | BC: 1.7078e-03
# Adam Epoch 01000 | Time: 0:00:07.182230 | Loss: 2.5486e-01 | PDE: 1.4355e-01 | IC: 1.4963e-02 | BC: 1.2138e-04
# Adam Epoch 01500 | Time: 0:00:10.799214 | Loss: 2.1218e-01 | PDE: 1.2210e-01 | IC: 1.1821e-02 | BC: 8.8998e-05
# Adam Epoch 02000 | Time: 0:00:14.408402 | Loss: 1.9639e-01 | PDE: 1.1375e-01 | IC: 1.0807e-02 | BC: 3.2163e-05
# Adam Epoch 02500 | Time: 0:00:17.939991 | Loss: 1.7217e-01 | PDE: 1.0117e-01 | IC: 9.1183e-03 | BC: 2.3594e-05
# Adam Epoch 03000 | Time: 0:00:21.487160 | Loss: 8.1409e-02 | PDE: 4.9013e-02 | IC: 3.9992e-03 | BC: 2.9356e-05
# Adam Epoch 03500 | Time: 0:00:25.057162 | Loss: 5.3048e-02 | PDE: 3.2759e-02 | IC: 2.3764e-03 | BC: 4.3508e-05
# Adam Epoch 04000 | Time: 0:00:28.604477 | Loss: 4.2505e-02 | PDE: 2.7082e-02 | IC: 1.7070e-03 | BC: 2.3446e-05
# Adam Epoch 04500 | Time: 0:00:32.180921 | Loss: 3.8925e-02 | PDE: 2.4624e-02 | IC: 1.4891e-03 | BC: 1.3982e-04
# Adam Epoch 04999 | Time: 0:00:35.750040 | Loss: 3.2340e-02 | PDE: 2.1163e-02 | IC: 1.1667e-03 | BC: 1.0560e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 3.2325e-02
# L-BFGS Epoch 0099 | Loss: 3.2306e-02
# Validation Loss: 4.0507e-02
# Model saved at: saved_models/arch2-16-32-8-1_wf1.25_wic5.0_wbc5.0_adam0.001_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 8, 1]
# Loss Weights -> PDE: 1.25, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.009414 | Loss: 2.6935e+00 | PDE: 1.0123e-02 | IC: 5.2759e-01 | BC: 8.5723e-03
# Adam Epoch 01000 | Time: 0:00:07.206300 | Loss: 2.2581e-01 | PDE: 1.2826e-01 | IC: 1.2837e-02 | BC: 2.5838e-04
# Adam Epoch 02000 | Time: 0:00:14.316867 | Loss: 1.8671e-01 | PDE: 1.0845e-01 | IC: 1.0140e-02 | BC: 8.8229e-05
# Adam Epoch 03000 | Time: 0:00:21.441634 | Loss: 1.0720e-01 | PDE: 6.4091e-02 | IC: 5.3614e-03 | BC: 5.5497e-05
# Adam Epoch 04000 | Time: 0:00:28.553765 | Loss: 6.3557e-02 | PDE: 3.9832e-02 | IC: 2.7410e-03 | BC: 1.2376e-05
# Adam Epoch 05000 | Time: 0:00:35.847287 | Loss: 4.6817e-02 | PDE: 3.0075e-02 | IC: 1.8185e-03 | BC: 2.6244e-05
# Adam Epoch 06000 | Time: 0:00:42.963474 | Loss: 3.7819e-02 | PDE: 2.4817e-02 | IC: 1.3390e-03 | BC: 2.0552e-05
# Adam Epoch 07000 | Time: 0:00:50.127621 | Loss: 3.4017e-02 | PDE: 2.2711e-02 | IC: 1.1113e-03 | BC: 1.4172e-05
# Adam Epoch 08000 | Time: 0:00:57.257684 | Loss: 4.3508e-02 | PDE: 3.0485e-02 | IC: 1.0331e-03 | BC: 4.7318e-05
# Adam Epoch 09000 | Time: 0:01:04.584310 | Loss: 3.0855e-02 | PDE: 2.0701e-02 | IC: 9.7974e-04 | BC: 1.6130e-05
# Adam Epoch 09999 | Time: 0:01:11.708612 | Loss: 2.8354e-02 | PDE: 1.9141e-02 | IC: 8.6871e-04 | BC: 1.6826e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 2.8351e-02
# L-BFGS Epoch 0099 | Loss: 2.8348e-02
# Validation Loss: 2.9503e-02
# Model saved at: saved_models/arch2-16-32-8-1_wf1.25_wic5.0_wbc5.0_adam0.001_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 8, 1]
# Loss Weights -> PDE: 1.5, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007631 | Loss: 2.3562e+00 | PDE: 9.5620e-04 | IC: 4.6549e-01 | BC: 5.4670e-03
# Adam Epoch 00500 | Time: 0:00:03.588626 | Loss: 2.3909e-01 | PDE: 1.1266e-01 | IC: 1.3776e-02 | BC: 2.4430e-04
# Adam Epoch 01000 | Time: 0:00:07.120949 | Loss: 1.8694e-01 | PDE: 8.4611e-02 | IC: 1.1886e-02 | BC: 1.1997e-04
# Adam Epoch 01500 | Time: 0:00:10.670404 | Loss: 9.9880e-02 | PDE: 5.1861e-02 | IC: 3.5673e-03 | BC: 8.5027e-04
# Adam Epoch 02000 | Time: 0:00:14.222206 | Loss: 5.3289e-02 | PDE: 2.8020e-02 | IC: 2.2061e-03 | BC: 4.5608e-05
# Adam Epoch 02500 | Time: 0:00:17.793102 | Loss: 4.4078e-02 | PDE: 2.3207e-02 | IC: 1.8042e-03 | BC: 4.9391e-05
# Adam Epoch 03000 | Time: 0:00:21.452632 | Loss: 3.7408e-02 | PDE: 1.9821e-02 | IC: 1.5046e-03 | BC: 3.0555e-05
# Adam Epoch 03500 | Time: 0:00:25.013896 | Loss: 3.4215e-02 | PDE: 1.8258e-02 | IC: 1.3434e-03 | BC: 2.2072e-05
# Adam Epoch 04000 | Time: 0:00:28.585217 | Loss: 4.7527e-02 | PDE: 2.2803e-02 | IC: 2.4781e-03 | BC: 1.8620e-04
# Adam Epoch 04500 | Time: 0:00:32.179032 | Loss: 2.6418e-02 | PDE: 1.4439e-02 | IC: 9.3206e-04 | BC: 1.9743e-05
# Adam Epoch 04999 | Time: 0:00:35.717082 | Loss: 2.5053e-02 | PDE: 1.3853e-02 | IC: 8.4363e-04 | BC: 1.1266e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 2.5048e-02
# L-BFGS Epoch 0099 | Loss: 2.5048e-02
# Validation Loss: 2.5979e-02
# Model saved at: saved_models/arch2-16-32-8-1_wf1.5_wic5.0_wbc5.0_adam0.005_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 8, 1]
# Loss Weights -> PDE: 1.5, IC: 5.0, BC: 5.0
# Adam: lr=0.005, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007870 | Loss: 3.0781e+00 | PDE: 3.5998e-02 | IC: 5.6223e-01 | BC: 4.2602e-02
# Adam Epoch 01000 | Time: 0:00:07.137651 | Loss: 8.3281e-02 | PDE: 4.1368e-02 | IC: 3.7197e-03 | BC: 5.2604e-04
# Adam Epoch 02000 | Time: 0:00:14.362991 | Loss: 3.9711e-02 | PDE: 2.0226e-02 | IC: 1.8556e-03 | BC: 1.8729e-05
# Adam Epoch 03000 | Time: 0:00:21.560086 | Loss: 3.5994e-02 | PDE: 1.7708e-02 | IC: 1.8556e-03 | BC: 3.0702e-05
# Adam Epoch 04000 | Time: 0:00:28.644448 | Loss: 3.3387e-02 | PDE: 1.6515e-02 | IC: 1.7162e-03 | BC: 6.7483e-06
# Adam Epoch 05000 | Time: 0:00:35.755317 | Loss: 3.2666e-02 | PDE: 1.6096e-02 | IC: 1.6249e-03 | BC: 7.9744e-05
# Adam Epoch 06000 | Time: 0:00:42.845060 | Loss: 3.0195e-02 | PDE: 1.4607e-02 | IC: 1.6501e-03 | BC: 6.8426e-06
# Adam Epoch 07000 | Time: 0:00:50.097492 | Loss: 4.1603e-02 | PDE: 1.7731e-02 | IC: 1.6569e-03 | BC: 1.3444e-03
# Adam Epoch 08000 | Time: 0:00:57.202389 | Loss: 2.7493e-02 | PDE: 1.3062e-02 | IC: 1.5731e-03 | BC: 7.0418e-06
# Adam Epoch 09000 | Time: 0:01:04.292773 | Loss: 1.8571e-02 | PDE: 1.0115e-02 | IC: 6.6195e-04 | BC: 1.7639e-05
# Adam Epoch 09999 | Time: 0:01:11.395511 | Loss: 1.6745e-02 | PDE: 9.1986e-03 | IC: 5.8420e-04 | BC: 5.1718e-06
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 1.6741e-02
# L-BFGS Epoch 0099 | Loss: 1.6741e-02
# Validation Loss: 1.7712e-02
# Model saved at: saved_models/arch2-16-32-8-1_wf1.5_wic5.0_wbc5.0_adam0.005_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 8, 1]
# Loss Weights -> PDE: 1.5, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=5000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007766 | Loss: 2.5000e+00 | PDE: 7.0008e-03 | IC: 3.9858e-01 | BC: 9.9322e-02
# Adam Epoch 00500 | Time: 0:00:03.660981 | Loss: 3.8359e-01 | PDE: 1.5594e-01 | IC: 2.7208e-02 | BC: 2.7287e-03
# Adam Epoch 01000 | Time: 0:00:07.221233 | Loss: 2.4743e-01 | PDE: 1.1272e-01 | IC: 1.5444e-02 | BC: 2.2431e-04
# Adam Epoch 01500 | Time: 0:00:10.864538 | Loss: 2.2956e-01 | PDE: 1.0552e-01 | IC: 1.4163e-02 | BC: 9.5492e-05
# Adam Epoch 02000 | Time: 0:00:14.474693 | Loss: 2.1951e-01 | PDE: 1.0174e-01 | IC: 1.3310e-02 | BC: 7.0022e-05
# Adam Epoch 02500 | Time: 0:00:18.035484 | Loss: 1.9863e-01 | PDE: 9.2809e-02 | IC: 1.1855e-02 | BC: 2.7716e-05
# Adam Epoch 03000 | Time: 0:00:21.595525 | Loss: 1.2862e-01 | PDE: 6.1285e-02 | IC: 7.2619e-03 | BC: 7.6726e-05
# Adam Epoch 03500 | Time: 0:00:25.144026 | Loss: 8.7251e-02 | PDE: 4.2826e-02 | IC: 4.5002e-03 | BC: 1.0208e-04
# Adam Epoch 04000 | Time: 0:00:28.713824 | Loss: 7.5770e-02 | PDE: 3.7819e-02 | IC: 3.7204e-03 | BC: 8.7984e-05
# Adam Epoch 04500 | Time: 0:00:32.255852 | Loss: 6.9426e-02 | PDE: 3.4998e-02 | IC: 3.3113e-03 | BC: 7.4324e-05
# Adam Epoch 04999 | Time: 0:00:35.953046 | Loss: 6.4654e-02 | PDE: 3.2915e-02 | IC: 2.9950e-03 | BC: 6.1112e-05
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 6.4645e-02
# L-BFGS Epoch 0099 | Loss: 6.4645e-02
# Validation Loss: 7.4583e-02
# Model saved at: saved_models/arch2-16-32-8-1_wf1.5_wic5.0_wbc5.0_adam0.001_5000_lbfgs0.01_100.pt
#
# ================================================================================
# Training with configuration:
# Architecture: [2, 16, 32, 8, 1]
# Loss Weights -> PDE: 1.5, IC: 5.0, BC: 5.0
# Adam: lr=0.001, epochs=10000 | LBFGS: lr=0.01, epochs=100
# Phase 1: Training with Adam optimizer
# Adam Epoch 00000 | Time: 0:00:00.007900 | Loss: 3.2844e+00 | PDE: 1.1052e-02 | IC: 6.0118e-01 | BC: 5.2382e-02
# Adam Epoch 01000 | Time: 0:00:07.069603 | Loss: 2.5887e-01 | PDE: 1.1546e-01 | IC: 1.6655e-02 | BC: 4.8069e-04
# Adam Epoch 02000 | Time: 0:00:14.174230 | Loss: 2.2479e-01 | PDE: 1.0506e-01 | IC: 1.3365e-02 | BC: 7.4492e-05
# Adam Epoch 03000 | Time: 0:00:21.282845 | Loss: 1.0755e-01 | PDE: 5.2370e-02 | IC: 5.7255e-03 | BC: 7.3115e-05
# Adam Epoch 04000 | Time: 0:00:28.571885 | Loss: 4.9699e-02 | PDE: 2.6373e-02 | IC: 1.9874e-03 | BC: 4.0527e-05
# Adam Epoch 05000 | Time: 0:00:35.666910 | Loss: 3.6279e-02 | PDE: 2.0100e-02 | IC: 1.2157e-03 | BC: 9.9140e-06
# Adam Epoch 06000 | Time: 0:00:42.765766 | Loss: 3.0911e-02 | PDE: 1.7544e-02 | IC: 9.1062e-04 | BC: 8.3280e-06
# Adam Epoch 07000 | Time: 0:00:49.874578 | Loss: 2.8521e-02 | PDE: 1.6306e-02 | IC: 7.9027e-04 | BC: 2.2124e-05
# Adam Epoch 08000 | Time: 0:00:56.957084 | Loss: 2.5699e-02 | PDE: 1.4678e-02 | IC: 7.2871e-04 | BC: 7.6264e-06
# Adam Epoch 09000 | Time: 0:01:04.217316 | Loss: 2.5236e-02 | PDE: 1.4401e-02 | IC: 6.9258e-04 | BC: 3.4398e-05
# Adam Epoch 09999 | Time: 0:01:11.315223 | Loss: 2.9710e-02 | PDE: 1.7112e-02 | IC: 6.2772e-04 | BC: 1.8052e-04
#
# Phase 2: Refinement with L-BFGS optimizer
# L-BFGS Epoch 0000 | Loss: 3.0950e-02
# L-BFGS Epoch 0099 | Loss: 1.7426e-02
# Validation Loss: 2.2162e-02
# Model saved at: saved_models/arch2-16-32-8-1_wf1.5_wic5.0_wbc5.0_adam0.001_10000_lbfgs0.01_100.pt
#
# ================================================================================
# Grid Search Complete!
# Best Validation Loss: 9.1658e-04
# Best Hyperparameters:
#   architecture: [2, 16, 32, 16, 1]
#   weight_f: 1.0
#   weight_ic: 5.0
#   weight_bc: 5.0
#   adam_lr: 0.005
#   adam_epochs: 10000
#   lbfgs_lr: 0.01
#   lbfgs_epochs: 100
#   model_path: saved_models/arch2-16-32-16-1_wf1.0_wic5.0_wbc5.0_adam0.005_10000_lbfgs0.01_100.pt
